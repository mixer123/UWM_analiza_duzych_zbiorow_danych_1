# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'cars.data'
df = pd.read_csv(url, delim_whitespace=True)

column_names = ['mpg', 'cylinders', 'displacement [cu]','horsepower','weight', 'acceleration', 'year', 'origin', 'name']
column_names
len(df.columns)
# Out:
# 9

# %%
df
# Out:
#      18.0  8  307.0  130.0   3504.  12.0  70  1 chevrolet chevelle malibu
# 0    15.0  8  350.0  165.0  3693.0  11.5  70  1         buick skylark 320
# 1    18.0  8  318.0  150.0  3436.0  11.0  70  1        plymouth satellite
# 2    16.0  8  304.0  150.0  3433.0  12.0  70  1             amc rebel sst
# 3    17.0  8  302.0  140.0  3449.0  10.5  70  1               ford torino
# 4    15.0  8  429.0  198.0  4341.0  10.0  70  1          ford galaxie 500
# ..    ... ..    ...    ...     ...   ...  .. ..                       ...
# 392  27.0  4  140.0  86.00  2790.0  15.6  82  1           ford mustang gl
# 393  44.0  4   97.0  52.00  2130.0  24.6  82  2                 vw pickup
# 394  32.0  4  135.0  84.00  2295.0  11.6  82  1             dodge rampage
# 395  28.0  4  120.0  79.00  2625.0  18.6  82  1               ford ranger
# 396  31.0  4  119.0  82.00  2720.0  19.4  82  1                chevy s-10
#
# [397 rows x 9 columns]

# %%
df.columns = ['mpg', 'cylinders', 'displacement [cu]','horsepower','weight', 'acceleration', 'year', 'origin', 'name']

# %%
df['horsepower']
# Out:
# 0      165.0
# 1      150.0
# 2      150.0
# 3      140.0
# 4      198.0
#        ...
# 392    86.00
# 393    52.00
# 394    84.00
# 395    79.00
# 396    82.00
# Name: horsepower, Length: 397, dtype: object

# %%
df = df.replace('?',0)

# %%
df['horsepower']=pd.to_numeric(df['horsepower'])

# %%
df.dtypes
# Out:
# mpg                  float64
# cylinders              int64
# displacement [cu]    float64
# horsepower           float64
# weight               float64
# acceleration         float64
# year                   int64
# origin                 int64
# name                  object
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.scatter(x=df['horsepower'], y=df['weight'])
plt.show()

# %%
df['horsepower']
# Out:
# 0      165.0
# 1      150.0
# 2      150.0
# 3      140.0
# 4      198.0
#        ...
# 392     86.0
# 393     52.0
# 394     84.0
# 395     79.0
# 396     82.0
# Name: horsepower, Length: 397, dtype: float64

# %%
df.horsepower.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(df['horsepower'], bins=10)
# Out:
# /tmp/ipykernel_8227/1507422317.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['horsepower'], bins=10)
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
df.boxplot(column='horsepower', by='cylinders')
# Out:
# <AxesSubplot:title={'center':'horsepower'}, xlabel='cylinders'>

# %%
fig, ax = plt.subplots()
df.groupby('year')['horsepower'].mean().plot(ax=ax,
label='horsepower')
ax.legend()

# %%
import matplotlib.pyplot as plt
print(plt.style.available)

plt.style.use(['classic'])
df.plot(kind='scatter', x='weight', y='horsepower')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# <AxesSubplot:xlabel='weight', ylabel='horsepower'>

# %% [markdown]
# 9. Try to plot average horsepower, acceleration and mpg per year. Show it on one plot. Use groupby.
# This should be only one line of code.

# %%
fig, ax = plt.subplots()
df.groupby('year')['horsepower','acceleration','mpg'].mean().plot(ax=ax,
label='horsepower')
plt.legend([df.horsepower, df.mpg])
# Out:
# /tmp/ipykernel_8227/3079628885.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('year')['horsepower','acceleration','mpg'].mean().plot(ax=ax,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8227/3079628885.py in <module>
#       2 df.groupby('year')['horsepower','acceleration','mpg'].mean().plot(ax=ax,
#       3 label='horsepower')
# ----> 4 plt.legend([df.horsepower, df.mpg])
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    2653 @_copy_docstring_and_deprecators(Axes.legend)
#    2654 def legend(*args, **kwargs):
# -> 2655     return gca().legend(*args, **kwargs)
#    2656
#    2657
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     303         if len(extra_args):
# ...
