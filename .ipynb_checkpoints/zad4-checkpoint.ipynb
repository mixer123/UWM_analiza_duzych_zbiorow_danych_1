# %%
import numpy as np

# %%
import pandas as pd
df1 = pd.read_csv("imports-85.csv")
df1.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
df1.columns
# Out:
# Index(['3', '?', 'alfa-romero', 'gas', 'std', 'two', 'convertible', 'rwd',
#        'front', '88.60', '168.80', '64.10', '48.80', '2548', 'dohc', 'four',
#        '130', 'mpfi', '3.47', '2.68', '9.00', '111', '5000', '21', '27',
#        '13495'],
#       dtype='object')

# %%
df = pd.read_csv("RadNet_Laboratory_Analysis.csv")
df.head()
# Out:
#   State Location Date Posted Date Collected Sample Type    Unit      Ba-140  \
# 0    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
# 1    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
# 2    AK   Juneau  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
# 3    AK     Nome  03/30/2011     03/22/2011  Air Filter  pCi/m3  Non-detect
# 4    AK     Nome  03/30/2011     03/23/2011  Air Filter  pCi/m3  Non-detect
#
#         Co-60      Cs-134 Cs-136      Cs-137  I-131       I-132       I-133  \
# 0  Non-detect  Non-detect    NaN  Non-detect  0.088  Non-detect  Non-detect
# 1  Non-detect  Non-detect    NaN  Non-detect  0.055  Non-detect  Non-detect
# 2  Non-detect      0.0057    NaN      0.0074  0.067  Non-detect  Non-detect
# 3  Non-detect  Non-detect    NaN  Non-detect  0.096  Non-detect  Non-detect
# 4  Non-detect  Non-detect    NaN  Non-detect   0.22  Non-detect  Non-detect
#
#   Te-129 Te-129m      Te-132
# ...

# %%
df.columns
# Out:
# Index(['State', 'Location', 'Date Posted', 'Date Collected', 'Sample Type',
#        'Unit', 'Ba-140', 'Co-60', 'Cs-134', 'Cs-136', 'Cs-137', 'I-131',
#        'I-132', 'I-133', 'Te-129', 'Te-129m', 'Te-132'],
#       dtype='object')

# %%
df.State
# Out:
# 0      ID
# 1      ID
# 2      AK
# 3      AK
# 4      AK
#        ..
# 601    CA
# 602    CA
# 603    UT
# 604    UT
# 605    NY
# Name: State, Length: 606, dtype: object

# %%
df.Location[2]
# Out:
# 'Juneau'

# %%
df.Location[1:3]
# Out:
# 1     Boise
# 2    Juneau
# Name: Location, dtype: object

# %%
df[df.State == "MN"]['I-131'].head()
# Out:
# 367    Non-detect
# 368          0.16
# 380    Non-detect
# 381    Non-detect
# 555          32.3
# Name: I-131, dtype: object

# %%
df.dtypes
# Out:
# State             object
# Location          object
# Date Posted       object
# Date Collected    object
# Sample Type       object
# Unit              object
# Ba-140            object
# Co-60             object
# Cs-134            object
# Cs-136            object
# Cs-137            object
# I-131             object
# I-132             object
# I-133             object
# Te-129            object
# Te-129m           object
# Te-132            object
# dtype: object

# %%
df.describe()
# Out:
#        State Location Date Posted Date Collected     Sample Type   Unit  \
# count    606      606         606            606             606    606
# unique    52      141          18             43               6      2
# top       AK    Boise  04/04/2011     03/28/2011  Drinking Water  pCi/l
# freq      70       26          98             49             153    377
#
#             Ba-140       Co-60      Cs-134      Cs-136      Cs-137  \
# count          605         605         606         506         606
# unique           1           1          53           6          53
# top     Non-detect  Non-detect  Non-detect  Non-detect  Non-detect
# freq           605         605         548         501         544
#
#              I-131       I-132       I-133      Te-129     Te-129m      Te-132
# count          606         606         605         506         506         606
# unique         171          25           2           2           3          40
# ...
